# %% [markdown]
# <a href="https://colab.research.google.com/github/merriekay/S23-CS167-Notes/blob/main/Day20_Neural_Networks_Part_III.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CS167: Day20
# ## Neural Networks Part III
#
# #### CS167: Machine Learning, Spring 2023
#
# Tuesday, April 11th, 2023
#
# 📆 [Course Schedule](https://docs.google.com/spreadsheets/d/e/2PACX-1vSvFV5Mz0_YZE1d5r3gQ8IMktE4cBAsJIlP30cl2GhEpSO0J-YWV62QokSDz-OcOCsEmxMuKpY0kVlR/pubhtml?gid=0&single=true) | 🙋[PollEverywhere](https://pollev.com/meredithmoore011) | 📜 [Syllabus](https://analytics.drake.edu/~moore/cs167_s23_syllabus.html) | 📬 [CodePost Login](https://codepost.io/login)

# %% [markdown]
# # Admin Stuff

# %% [markdown]
# Grading--I owe you grades for:
# - Project #1
# - Quiz #2
# - Notebook #5

# %% [markdown]
# You should be working on:
# - [Notebook #6](https://classroom.github.com/a/pUdpmxBH) is released today, due April 17th by 11:59pm

# %% [markdown]
# # Announcement
#
# __Thursday 4/13__: We'll have guest speakers from Berkshire Hathaway
#
# <div>
# <img src="images/berkshire_hathaway_energy.jpeg" width=250/>
# </div>

# %% [markdown]
# ## Load your data:

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas
path = 'datasets/irisData.csv' #'/content/drive/MyDrive/CS167/datasets/irisData.csv'
data = pandas.read_csv(path)

# %% [markdown]
# ## Quick Review:

# %% [markdown]
# # Neural Network Summary
#
# Neural Networks are effective in __finding non-linear patterns__ in the training data.
# - can be applied to __regression__ or __classification__.
# - __backpropagation__ tunes the weights over a neural network using __gradient descent__ to iteratively reduce the error in the network.
# - __Overfitting__ the training data is common and is important to avoid.
# - The following parameters shoudl be tuned when using neural networks:
#     - number of epochs
#     - structure of the network (depth, width)
#     - activation function
#     - eta (learning rate)

# %% [markdown]
# # Training a Neural Network to Predict Taxi Fares:
#
# Download `taxi-fares.csv` from Blackboard and put it in your Google Drive. This data is from the New York City Taxi and LImousine Commision and includes data about taxi fares.
#
# Let's start by loading in our dataset and doing some pre-processing.

# %%
from math import sqrt
import pandas as pd

#load dataset
path = 'datasets/taxi-fares.csv' #'/content/drive/MyDrive/CS167/datasets/taxi-fares.csv'
df = pd.read_csv(path, parse_dates=['pickup_datetime'])

# data prep
df = df[df['passenger_count'] == 1]
df = df.drop(['key', 'passenger_count'], axis=1)
 
for i, row in df.iterrows():
    dt = row['pickup_datetime']
    df.at[i, 'day_of_week'] = dt.weekday()
    df.at[i, 'pickup_time'] = dt.hour
    x = (row['dropoff_longitude'] - row['pickup_longitude']) * 54.6
    y = (row['dropoff_latitude'] - row['pickup_latitude']) * 69.0
    distance = sqrt(x**2 + y**2)
    df.at[i, 'distance'] = distance
 
df.drop(['pickup_datetime', 'pickup_longitude', 'pickup_latitude',
         'dropoff_longitude', 'dropoff_latitude'], axis=1, inplace=True)
 
df = df[(df['distance'] > 1.0) & (df['distance'] < 10.0)]
df = df[(df['fare_amount'] > 0.0) & (df['fare_amount'] < 50.0)]
df.head()
# Out:
#    fare_amount  day_of_week  pickup_time  distance
# 2          6.1          0.0         15.0  1.038136
# 4         10.5          5.0         10.0  2.924341
# 5         15.3          4.0         20.0  4.862893
# 8          7.7          5.0          1.0  2.603493
# 9          8.9          3.0         16.0  1.365739

# %% [markdown]
# ## 🙋 PollEverywhere

# %% [markdown]
# # Build Your Model:

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
 
model = Sequential()
model.add(Dense(512, activation='relu', input_dim=3))
model.add(Dense(512, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mae', metrics=['mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               2048
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 265,217
# Trainable params: 265,217
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# - What is the _depth_ of this model?
# - How many attributes are input to the model?
# - What is the _width_ of the hidden layers of this model?
# - What type of Gradient Descent is being used to train this model?
# - What metrics are we keeping track of?

# %% [markdown]
# # Now, let's train our model:

# %%
x = df.drop('fare_amount', axis=1)
y = df['fare_amount']

hist = model.fit(x, y, validation_split=0.2, epochs=50, batch_size=100)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 18638 samples, validate on 4660 samples
# Epoch 1/50
# 18638/18638 [==============================] - 2s 84us/sample - loss: 2.9052 - mae: 2.9052 - val_loss: 2.4235 - val_mae: 2.4235
# Epoch 2/50
# 18638/18638 [==============================] - 1s 57us/sample - loss: 2.3861 - mae: 2.3861 - val_loss: 2.3906 - val_mae: 2.3906
# Epoch 3/50
# 18638/18638 [==============================] - 1s 61us/sample - loss: 2.3806 - mae: 2.3806 - val_loss: 2.3907 - val_mae: 2.3907
# Epoch 4/50
# 18638/18638 [==============================] - 1s 60us/sample - loss: 2.3904 - mae: 2.3904 - val_loss: 2.3561 - val_mae: 2.3561
# Epoch 5/50
# 18638/18638 [==============================] - 1s 74us/sample - loss: 2.3629 - mae: 2.3629 - val_loss: 2.3583 - val_mae: 2.3583
# Epoch 6/50
# 18638/18638 [==============================] - 1s 60us/sample - loss: 2.3561 - mae: 2.3561 - val_loss: 2.3715 - val_mae: 2.3715
# Epoch 7/50
# 18638/18638 [==============================] - 1s 60us/sample - loss: 2.3684 - mae: 2.3684 - val_loss: 2.3385 - val_mae: 2.3385
# Epoch 8/50
# 18638/18638 [==============================] - 1s 64us/sample - loss: 2.3527 - mae: 2.3527 - val_loss: 2.3440 - val_mae: 2.3440
# Epoch 9/50
# 18638/18638 [==============================] - 1s 61us/sample - loss: 2.3521 - mae: 2.3521 - val_loss: 2.3638 - val_mae: 2.3638
# Epoch 10/50
# 18638/18638 [==============================] - 1s 62us/sample - loss: 2.3570 - mae: 2.3570 - val_loss: 2.3454 - val_mae: 2.3454
# Epoch 11/50
# 18638/18638 [==============================] - 1s 66us/sample - loss: 2.3548 - mae: 2.3548 - val_loss: 2.4170 - val_mae: 2.4170
# Epoch 12/50
# 18638/18638 [==============================] - 1s 65us/sample - loss: 2.3560 - mae: 2.3560 - val_loss: 2.3615 - val_mae: 2.3615
# Epoch 13/50
# 18638/18638 [==============================] - 1s 67us/sample - loss: 2.3485 - mae: 2.3485 - val_loss: 2.3761 - val_mae: 2.3761
# Epoch 14/50
# 18638/18638 [==============================] - 1s 67us/sample - loss: 2.3460 - mae: 2.3460 - val_loss: 2.5548 - val_mae: 2.5548
# Epoch 15/50
# 18638/18638 [==============================] - 1s 63us/sample - loss: 2.3521 - mae: 2.3521 - val_loss: 2.3250 - val_mae: 2.3250
# Epoch 16/50
# 18638/18638 [==============================] - 1s 62us/sample - loss: 2.3366 - mae: 2.3366 - val_loss: 2.3515 - val_mae: 2.3515
# Epoch 17/50
# 18638/18638 [==============================] - 1s 64us/sample - loss: 2.3360 - mae: 2.3360 - val_loss: 2.3490 - val_mae: 2.3490
# Epoch 18/50
# 18638/18638 [==============================] - 1s 64us/sample - loss: 2.3347 - mae: 2.3347 - val_loss: 2.3709 - val_mae: 2.3709
# Epoch 19/50
# 18638/18638 [==============================] - 1s 63us/sample - loss: 2.3319 - mae: 2.3319 - val_loss: 2.3124 - val_mae: 2.3124
# Epoch 20/50
# 18638/18638 [==============================] - 1s 62us/sample - loss: 2.3255 - mae: 2.3255 - val_loss: 2.3161 - val_mae: 2.3161
# Epoch 21/50
# 18638/18638 [==============================] - 1s 61us/sample - loss: 2.3327 - mae: 2.3327 - val_loss: 2.3366 - val_mae: 2.3366
# Epoch 22/50
# 18638/18638 [==============================] - 1s 63us/sample - loss: 2.3327 - mae: 2.3327 - val_loss: 2.3416 - val_mae: 2.3416
# Epoch 23/50
# 18638/18638 [==============================] - 1s 63us/sample - loss: 2.3234 - mae: 2.3234 - val_loss: 2.3177 - val_mae: 2.3177
# Epoch 24/50
# 18638/18638 [==============================] - 1s 66us/sample - loss: 2.3131 - mae: 2.3131 - val_loss: 2.3068 - val_mae: 2.3068
# Epoch 25/50
# 18638/18638 [==============================] - 1s 66us/sample - loss: 2.3168 - mae: 2.3168 - val_loss: 2.3255 - val_mae: 2.3255
# Epoch 26/50
# 18638/18638 [==============================] - 1s 64us/sample - loss: 2.3108 - mae: 2.3108 - val_loss: 2.3075 - val_mae: 2.3075
# Epoch 27/50
# 18638/18638 [==============================] - 1s 65us/sample - loss: 2.3228 - mae: 2.3228 - val_loss: 2.3214 - val_mae: 2.3214
# Epoch 28/50
# 18638/18638 [==============================] - 1s 65us/sample - loss: 2.3183 - mae: 2.3183 - val_loss: 2.3334 - val_mae: 2.3334
# Epoch 29/50
# 18638/18638 [==============================] - 1s 66us/sample - loss: 2.3220 - mae: 2.3220 - val_loss: 2.3114 - val_mae: 2.3114
# Epoch 30/50
# 18638/18638 [==============================] - 1s 67us/sample - loss: 2.3206 - mae: 2.3206 - val_loss: 2.3320 - val_mae: 2.3320
# Epoch 31/50
# 18638/18638 [==============================] - 1s 68us/sample - loss: 2.3140 - mae: 2.3140 - val_loss: 2.3260 - val_mae: 2.3260
# Epoch 32/50
# 18638/18638 [==============================] - 1s 67us/sample - loss: 2.3110 - mae: 2.3110 - val_loss: 2.2979 - val_mae: 2.2979
# Epoch 33/50
# 18638/18638 [==============================] - 1s 68us/sample - loss: 2.3284 - mae: 2.3284 - val_loss: 2.3164 - val_mae: 2.3164
# Epoch 34/50
# 18638/18638 [==============================] - 1s 69us/sample - loss: 2.3187 - mae: 2.3187 - val_loss: 2.2948 - val_mae: 2.2948
# Epoch 35/50
# 18638/18638 [==============================] - 1s 70us/sample - loss: 2.3109 - mae: 2.3110 - val_loss: 2.2970 - val_mae: 2.2970
# Epoch 36/50
# 18638/18638 [==============================] - 1s 68us/sample - loss: 2.3045 - mae: 2.3045 - val_loss: 2.3218 - val_mae: 2.3218
# Epoch 37/50
# 18638/18638 [==============================] - 1s 66us/sample - loss: 2.3036 - mae: 2.3036 - val_loss: 2.2959 - val_mae: 2.2959
# Epoch 38/50
# 18638/18638 [==============================] - 1s 65us/sample - loss: 2.2963 - mae: 2.2963 - val_loss: 2.2848 - val_mae: 2.2848
# Epoch 39/50
# 18638/18638 [==============================] - 1s 66us/sample - loss: 2.3185 - mae: 2.3185 - val_loss: 2.3407 - val_mae: 2.3407
# Epoch 40/50
# 18638/18638 [==============================] - 1s 64us/sample - loss: 2.3062 - mae: 2.3062 - val_loss: 2.3270 - val_mae: 2.3270
# Epoch 41/50
# 18638/18638 [==============================] - 1s 64us/sample - loss: 2.3130 - mae: 2.3130 - val_loss: 2.3054 - val_mae: 2.3054
# Epoch 42/50
# 18638/18638 [==============================] - 1s 65us/sample - loss: 2.3028 - mae: 2.3028 - val_loss: 2.3065 - val_mae: 2.3065
# Epoch 43/50
# 18638/18638 [==============================] - 1s 64us/sample - loss: 2.3145 - mae: 2.3145 - val_loss: 2.2918 - val_mae: 2.2918
# Epoch 44/50
# 18638/18638 [==============================] - 1s 69us/sample - loss: 2.3007 - mae: 2.3007 - val_loss: 2.3024 - val_mae: 2.3024
# Epoch 45/50
# 18638/18638 [==============================] - 1s 63us/sample - loss: 2.3066 - mae: 2.3066 - val_loss: 2.2707 - val_mae: 2.2707
# Epoch 46/50
# 18638/18638 [==============================] - 1s 64us/sample - loss: 2.2991 - mae: 2.2991 - val_loss: 2.2908 - val_mae: 2.2908
# Epoch 47/50
# 18638/18638 [==============================] - 1s 65us/sample - loss: 2.2932 - mae: 2.2931 - val_loss: 2.2730 - val_mae: 2.2730
# Epoch 48/50
# 18638/18638 [==============================] - 1s 65us/sample - loss: 2.2917 - mae: 2.2917 - val_loss: 2.2654 - val_mae: 2.2654
# Epoch 49/50
# 18638/18638 [==============================] - 1s 65us/sample - loss: 2.2888 - mae: 2.2888 - val_loss: 2.2779 - val_mae: 2.2779
# Epoch 50/50
# 18638/18638 [==============================] - 1s 64us/sample - loss: 2.2870 - mae: 2.2870 - val_loss: 2.2803 - val_mae: 2.2803

# %% [markdown]
# # And take a look at the results:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

err = hist.history['mae']
val_err = hist.history['val_mae']
epochs = range(1, len(err) + 1)

plt.plot(epochs, err, '-', label='Training MAE')
plt.plot(epochs, val_err, ':', label='Validation MAE')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error')
plt.legend(loc='upper right')
plt.plot()
# Out:
# []

# %% [markdown]
# # Last, but not least, let's make some predictions:

# %%
from sklearn.metrics import r2_score

r2_score(y, model.predict(x))
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# 0.7453605865721533

# %% [markdown]
# Estimate what it will cost to hire a taxi for a 2-mile trip at 5:00pm on a Friday afternoon:
# - day of the week `[ Monday:0, Tuesday:1, Wednesday:2, Thursday:3, Friday:4, Saturday:5, Sunday:6]`
# - time, military time
# - distance in miles

# %%
import numpy as np

# day of the week, time, and distance
model.predict(np.array([[4, 17, 2.0]]))
# Out:
# array([[10.744503]], dtype=float32)

# %% [markdown]
# # ✨ New Material

# %% [markdown]
# To talk about:
# - practicing building models
# - sensitive data
# - imbalanced datasets
# - saving and loading models

# %% [markdown]
# # Fraud Detection with Neural Networks
#
# Credit card companies use ML models to examine transactions in real time and identify ones that are likely to be fraudulent.
# - the features they use contain sensitive information (credit card numbers, purchase history, etc)
#
# ## 💬 Group Discussion:
# - the anonymity of the customers should be preserved somehow, while keeping as much data as possible. Any ideas how we might go about doing this?

# %% [markdown]
# > Go ahead and download the `creditcard.csv` file from Bb.
#
# - `Time` is the number of seconds elapsed since the first transaction
# - `Class` tells us whether the transaction is legitimate (0) or fraudulent (1)
# - `Amount` is the amount the transaction was for.
# - The other columns `V1` - `V28` were generated using PCA from information that isn't revelaed to us.

# %%
import pandas as pd

path = 'datasets/creditcard.csv' # #'/content/drive/MyDrive/CS167/datasets/creditcard.csv'
df = pd.read_csv(path)
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# 5  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 6  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055  0.750137
# 7 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709 -0.415267
# 8  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592  0.373205
# 9  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794 -0.385050 -0.069733
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
# 5  0.105915  0.253844  0.081080    3.67      0
# 6 -0.257237  0.034507  0.005168    4.99      0
# 7 -0.051634 -1.206921 -1.085339   40.80      0
# 8 -0.384157  0.011747  0.142404   93.20      0
# 9  0.094199  0.246219  0.083076    3.68      0
#
# [10 rows x 31 columns]

# %% [markdown]
# # Imbalanced Datasets:
#
# In the real world, we rarely get the privilege of working with nicely balanced datasets. This dataset is a great example of this.
#
# What do I mean by a __balanced dataset__?
# - relatively equal distribution of the classes we're trying to predict.
#
# How might we check to see if our dataset is balanced?

# %%
df.Class.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# We'll use [`train_test_split`](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)'s `stratify` parameter to ensure that the ratio of legimate and fraudulent transactions is consisten in the training and the testing dataset:

# %%
from sklearn.model_selection import train_test_split

x = df.drop(['Time', 'Class'], axis=1)
y = df['Class']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=0)

# %% [markdown]
# # Exercise #1: Build our network
#
# What kind of machine learning are we doing here? Classifiation or regression?

# %% [markdown]
# Let's build a network that has:
# - `input_dim=29`
# - 1 hidden layer with 128 neurons
# - `relu` for the activation function of the hidden layer
# - a `Dense` output layer with a `sigmoid` activation function.
#
# when you're done, print out the summary of your model.

# %%
# your code here:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential() 

#build your model here:
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 128)               3840
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 3,969
# Trainable params: 3,969
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile your model with loss='binary_crossentropy', optimizer='adam', and metrics=['accuracy']
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# train your model for 10 epochs, with batch_size=100
hist = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=10, batch_size=100)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 227845 samples, validate on 56962 samples
# Epoch 1/10
# 227845/227845 [==============================] - 6s 28us/sample - loss: 0.0146 - accuracy: 0.9985 - val_loss: 0.0083 - val_accuracy: 0.9992
# Epoch 2/10
# 227845/227845 [==============================] - 6s 27us/sample - loss: 0.0072 - accuracy: 0.9992 - val_loss: 0.0062 - val_accuracy: 0.9993
# Epoch 3/10
# 227845/227845 [==============================] - 6s 28us/sample - loss: 0.0067 - accuracy: 0.9992 - val_loss: 0.0074 - val_accuracy: 0.9993
# Epoch 4/10
# 227845/227845 [==============================] - 7s 30us/sample - loss: 0.0065 - accuracy: 0.9993 - val_loss: 0.0047 - val_accuracy: 0.9992
# Epoch 5/10
# 227845/227845 [==============================] - 6s 29us/sample - loss: 0.0046 - accuracy: 0.9993 - val_loss: 0.0050 - val_accuracy: 0.9992
# Epoch 6/10
# 227845/227845 [==============================] - 7s 29us/sample - loss: 0.0052 - accuracy: 0.9994 - val_loss: 0.0059 - val_accuracy: 0.9992
# Epoch 7/10
# 227845/227845 [==============================] - 7s 29us/sample - loss: 0.0056 - accuracy: 0.9994 - val_loss: 0.0045 - val_accuracy: 0.9993
# Epoch 8/10
# 227845/227845 [==============================] - 7s 32us/sample - loss: 0.0041 - accuracy: 0.9994 - val_loss: 0.0043 - val_accuracy: 0.9994
# Epoch 9/10
# 227845/227845 [==============================] - 7s 30us/sample - loss: 0.0042 - accuracy: 0.9994 - val_loss: 0.0060 - val_accuracy: 0.9992
# Epoch 10/10
# 227845/227845 [==============================] - 7s 30us/sample - loss: 0.0038 - accuracy: 0.9995 - val_loss: 0.0043 - val_accuracy: 0.9994

# %% [markdown]
# Plot the training accuracy and validation acuracy:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

acc = hist.history['accuracy']
val = hist.history['val_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, '-', label='Training accuracy')
plt.plot(epochs, val, ':', label='Validation accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.plot()
# Out:
# []

# %% [markdown]
# Visualize the results as a confusion matrix:

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import matplotlib.pyplot as plt

sns.reset_orig()
y_predicted = model.predict(x_test) > 0.5 # it will be 1 if > 0.5 and 0 otherwise
labels = ['Legitimate', 'Fraudulent']

cm = confusion_matrix(y_test, y_predicted, labels=df.Class.unique())
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=labels)
disp.plot()
plt.show()
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>

# %% [markdown]
# Your results will vary, but in this example, the model caught 74 of 98 fraudulent cases, and missclassified 9 legitimate charges as fraudulent.
#
# What is the accuracy of fraudulent cases?

# %%
total_fraudulent = 24 + 74
correct = 74
correct / total_fraudulent
# Out:
# 0.7551020408163265

# %% [markdown]
# ## Things to consider:
#
# - how might we make predictions with this model?

# %% [markdown]
# # Multiclass Classification with Neural Networks:
#
# We just did an example where we were doing `binary classification`. What things do we need to change to be able to do `multiclass classification`?

# %% [markdown]
# - the output layer needs to contain _one neuron per output class_
# - the output layer should use _______ activation instead of `sigmoid`.
# - the loss function wil be `sparse_cateogrical_crossentropy`

# %% [markdown]
# ## Training a Neural Network to Recognize Faces
#
# We're going to use the [Labeled Faces in the Wild (LFW)](http://vis-www.cs.umass.edu/lfw/) dataset.
#
# We'll learn that Convolutional Neural Networks will be able to do a better job on this data than regular Neural networks. But let's give it a shot:

# %% [markdown]
# # Load the dataset:
#
# This dataset contains more than 13,000 facial images collected from tne internet.
#
# Of the more than 5000 people represented in the dataset 1680 have two or more facial images, while only five have 100 or more.
#
# We'll set the minimum number of faces per person to 100, which means that five sets of faces corresponding to five famous people will be imported.

# %%
import pandas as pd
from sklearn.datasets import fetch_lfw_people

faces = fetch_lfw_people(min_faces_per_person=100, slice_=None)
faces.images = faces.images[:, 35:97, 39:86]
faces.data = faces.images.reshape(faces.images.shape[0], faces.images.shape[1] * faces.images.shape[2])
image_count = faces.images.shape[0]
image_height = faces.images.shape[1]
image_width = faces.images.shape[2]
class_count = len(faces.target_names)

print(faces.target_names)
print(faces.images.shape)
# Out:
# ['Colin Powell' 'Donald Rumsfeld' 'George W Bush' 'Gerhard Schroeder'
#  'Tony Blair']
# (1140, 62, 47)

# %% [markdown]
# In total, 1140 facial images were loaded. AFter cropping, each image measures 47x 62 pixels for a total of 2914 pixels per image. That means we're workign with a dataset containing 2914 feature columns.
#
# Use the folloiwng code to show the first 24 images in the dataset and the poeple to whom the faces belong.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, ax = plt.subplots(3, 8, figsize=(18, 10))
for i, axi in enumerate(ax.flat):
    axi.imshow(faces.images[i], cmap='gist_gray')
    axi.set(xticks=[], yticks=[], xlabel=faces.target_names[faces.target[i]])

# %% [markdown]
# ## 💬 Group Exercise
#
# Check the balance of the dataset:

# %% [markdown]
# The dataset is not very well balanced, and that's a concern because classification models are best trained with balanced datasets. Use the following code to build a dataset containing 100 images of each person.

# %%
import numpy as np

mask = np.zeros(faces.target.shape, dtype=bool)

for target in np.unique(faces.target):
    mask[np.where(faces.target == target)[0][:100]] = 1
    
x_faces = faces.data[mask]
y_faces = faces.target[mask]
x_faces.shape
# Out:
# (500, 2914)

# %% [markdown]
# ## Split the data for training and testing:

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_faces, y_faces, train_size=0.8, stratify=y_faces, random_state=0)

# %% [markdown]
# ## Build and train a neural network:
#
# Start by using Keras to build and train an eural network containnig:
# - one hidden layer with 512 neurons.
# - `sparse_categorical_crossentropy` as the loss function
# - a `softmax` activation function on our output layer since this is a multiclass classification task
# -  `adam` as our optimization algorithm

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
 
model = Sequential()
# build your model here:
model.add(Dense(512, activation='relu', input_shape=(image_width * image_height,)))
model.add(Dense(class_count, activation='softmax'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               1492480
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 2565
# =================================================================
# Total params: 1,495,045
# Trainable params: 1,495,045
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now, train your model:

# %%
hist = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100, batch_size=20)
# Out:
# Train on 400 samples, validate on 100 samples
# Epoch 1/100
# 400/400 [==============================] - 1s 2ms/sample - loss: 1297.4845 - accuracy: 0.2050 - val_loss: 645.2356 - val_accuracy: 0.2000
# Epoch 2/100
# 400/400 [==============================] - 0s 584us/sample - loss: 279.8176 - accuracy: 0.2300 - val_loss: 138.3371 - val_accuracy: 0.2000
# Epoch 3/100
# 400/400 [==============================] - 0s 605us/sample - loss: 60.1394 - accuracy: 0.3650 - val_loss: 57.9330 - val_accuracy: 0.3800
# Epoch 4/100
# 400/400 [==============================] - 0s 571us/sample - loss: 27.1603 - accuracy: 0.4250 - val_loss: 18.7936 - val_accuracy: 0.4300
# Epoch 5/100
# 400/400 [==============================] - 0s 559us/sample - loss: 12.9677 - accuracy: 0.5875 - val_loss: 31.6476 - val_accuracy: 0.4200
# Epoch 6/100
# 400/400 [==============================] - 0s 575us/sample - loss: 16.9637 - accuracy: 0.5450 - val_loss: 7.5053 - val_accuracy: 0.6600
# Epoch 7/100
# 400/400 [==============================] - 0s 571us/sample - loss: 14.8048 - accuracy: 0.5775 - val_loss: 25.4196 - val_accuracy: 0.5600
# Epoch 8/100
# 400/400 [==============================] - 0s 564us/sample - loss: 22.4730 - accuracy: 0.5225 - val_loss: 39.2780 - val_accuracy: 0.4400
# Epoch 9/100
# 400/400 [==============================] - 0s 573us/sample - loss: 13.6082 - accuracy: 0.6175 - val_loss: 27.7784 - val_accuracy: 0.4400
# Epoch 10/100
# 400/400 [==============================] - 0s 572us/sample - loss: 25.9441 - accuracy: 0.5225 - val_loss: 11.9853 - val_accuracy: 0.5900
# Epoch 11/100
# 400/400 [==============================] - 0s 574us/sample - loss: 25.4176 - accuracy: 0.5600 - val_loss: 15.7655 - val_accuracy: 0.5900
# Epoch 12/100
# 400/400 [==============================] - 0s 561us/sample - loss: 15.8451 - accuracy: 0.5875 - val_loss: 39.7312 - val_accuracy: 0.4000
# Epoch 13/100
# 400/400 [==============================] - 0s 564us/sample - loss: 21.1752 - accuracy: 0.5700 - val_loss: 22.8686 - val_accuracy: 0.6200
# Epoch 14/100
# 400/400 [==============================] - 0s 581us/sample - loss: 9.1095 - accuracy: 0.6950 - val_loss: 11.4777 - val_accuracy: 0.6300
# Epoch 15/100
# 400/400 [==============================] - 0s 550us/sample - loss: 6.5495 - accuracy: 0.7400 - val_loss: 15.0985 - val_accuracy: 0.6000
# Epoch 16/100
# 400/400 [==============================] - 0s 606us/sample - loss: 6.2551 - accuracy: 0.7650 - val_loss: 6.1521 - val_accuracy: 0.7300
# Epoch 17/100
# 400/400 [==============================] - 0s 603us/sample - loss: 4.1533 - accuracy: 0.7925 - val_loss: 16.9008 - val_accuracy: 0.6000
# Epoch 18/100
# 400/400 [==============================] - 0s 604us/sample - loss: 12.7389 - accuracy: 0.6625 - val_loss: 30.3898 - val_accuracy: 0.5000
# Epoch 19/100
# 400/400 [==============================] - 0s 606us/sample - loss: 15.2866 - accuracy: 0.6500 - val_loss: 48.9517 - val_accuracy: 0.3700
# Epoch 20/100
# 400/400 [==============================] - 0s 613us/sample - loss: 14.8740 - accuracy: 0.6375 - val_loss: 31.8523 - val_accuracy: 0.5000
# Epoch 21/100
# 400/400 [==============================] - 0s 643us/sample - loss: 8.2266 - accuracy: 0.7150 - val_loss: 46.9254 - val_accuracy: 0.4500
# Epoch 22/100
# 400/400 [==============================] - 0s 606us/sample - loss: 17.1772 - accuracy: 0.6250 - val_loss: 10.3550 - val_accuracy: 0.6900
# Epoch 23/100
# 400/400 [==============================] - 0s 622us/sample - loss: 8.1174 - accuracy: 0.7300 - val_loss: 24.7368 - val_accuracy: 0.4600
# Epoch 24/100
# 400/400 [==============================] - 0s 613us/sample - loss: 12.0483 - accuracy: 0.6550 - val_loss: 6.2690 - val_accuracy: 0.7400
# Epoch 25/100
# 400/400 [==============================] - 0s 593us/sample - loss: 6.5036 - accuracy: 0.7275 - val_loss: 9.7506 - val_accuracy: 0.6200
# Epoch 26/100
# 400/400 [==============================] - 0s 654us/sample - loss: 4.9940 - accuracy: 0.7775 - val_loss: 14.4129 - val_accuracy: 0.6100
# Epoch 27/100
# 400/400 [==============================] - 0s 666us/sample - loss: 5.0229 - accuracy: 0.8000 - val_loss: 11.9455 - val_accuracy: 0.6600
# Epoch 28/100
# 400/400 [==============================] - 0s 637us/sample - loss: 1.7389 - accuracy: 0.8800 - val_loss: 9.7994 - val_accuracy: 0.7400
# Epoch 29/100
# 400/400 [==============================] - 0s 638us/sample - loss: 2.5824 - accuracy: 0.8600 - val_loss: 4.1391 - val_accuracy: 0.7800
# Epoch 30/100
# 400/400 [==============================] - 0s 641us/sample - loss: 1.4885 - accuracy: 0.9000 - val_loss: 9.2260 - val_accuracy: 0.6400
# Epoch 31/100
# 400/400 [==============================] - 0s 693us/sample - loss: 5.4730 - accuracy: 0.7675 - val_loss: 16.4419 - val_accuracy: 0.5800
# Epoch 32/100
# 400/400 [==============================] - 0s 695us/sample - loss: 4.4581 - accuracy: 0.8000 - val_loss: 10.3340 - val_accuracy: 0.6800
# Epoch 33/100
# 400/400 [==============================] - 0s 682us/sample - loss: 3.8259 - accuracy: 0.8250 - val_loss: 10.3038 - val_accuracy: 0.6300
# Epoch 34/100
# 400/400 [==============================] - 0s 700us/sample - loss: 3.8690 - accuracy: 0.7775 - val_loss: 13.8528 - val_accuracy: 0.6100
# Epoch 35/100
# 400/400 [==============================] - 0s 734us/sample - loss: 4.0756 - accuracy: 0.7975 - val_loss: 8.4090 - val_accuracy: 0.6100
# Epoch 36/100
# 400/400 [==============================] - 0s 840us/sample - loss: 2.5762 - accuracy: 0.8375 - val_loss: 10.4062 - val_accuracy: 0.6600
# Epoch 37/100
# 400/400 [==============================] - 0s 776us/sample - loss: 1.6187 - accuracy: 0.8850 - val_loss: 7.5174 - val_accuracy: 0.7000
# Epoch 38/100
# 400/400 [==============================] - 0s 771us/sample - loss: 3.5146 - accuracy: 0.8150 - val_loss: 20.5185 - val_accuracy: 0.5700
# Epoch 39/100
# 400/400 [==============================] - 0s 755us/sample - loss: 10.5333 - accuracy: 0.7000 - val_loss: 24.6569 - val_accuracy: 0.5500
# Epoch 40/100
# 400/400 [==============================] - 0s 733us/sample - loss: 9.4051 - accuracy: 0.6850 - val_loss: 13.9086 - val_accuracy: 0.5300
# Epoch 41/100
# 400/400 [==============================] - 0s 812us/sample - loss: 11.4382 - accuracy: 0.6850 - val_loss: 8.5777 - val_accuracy: 0.7100
# Epoch 42/100
# 400/400 [==============================] - 0s 758us/sample - loss: 2.3574 - accuracy: 0.8300 - val_loss: 9.0486 - val_accuracy: 0.6700
# Epoch 43/100
# 400/400 [==============================] - 0s 729us/sample - loss: 3.7053 - accuracy: 0.8025 - val_loss: 7.4964 - val_accuracy: 0.7200
# Epoch 44/100
# 400/400 [==============================] - 0s 712us/sample - loss: 1.7422 - accuracy: 0.8675 - val_loss: 4.6216 - val_accuracy: 0.6900
# Epoch 45/100
# 400/400 [==============================] - 0s 715us/sample - loss: 1.3111 - accuracy: 0.8875 - val_loss: 4.7549 - val_accuracy: 0.7300
# Epoch 46/100
# 400/400 [==============================] - 0s 715us/sample - loss: 0.7330 - accuracy: 0.9275 - val_loss: 3.6481 - val_accuracy: 0.8200
# Epoch 47/100
# 400/400 [==============================] - 0s 745us/sample - loss: 0.8884 - accuracy: 0.9175 - val_loss: 5.7796 - val_accuracy: 0.7200
# Epoch 48/100
# 400/400 [==============================] - 0s 693us/sample - loss: 3.8296 - accuracy: 0.8075 - val_loss: 7.9050 - val_accuracy: 0.6500
# Epoch 49/100
# 400/400 [==============================] - 0s 702us/sample - loss: 8.0418 - accuracy: 0.7375 - val_loss: 6.9455 - val_accuracy: 0.7000
# Epoch 50/100
# 400/400 [==============================] - 0s 681us/sample - loss: 2.6668 - accuracy: 0.8500 - val_loss: 9.4669 - val_accuracy: 0.7300
# Epoch 51/100
# 400/400 [==============================] - 0s 643us/sample - loss: 2.5620 - accuracy: 0.8675 - val_loss: 9.2964 - val_accuracy: 0.7000
# Epoch 52/100
# 400/400 [==============================] - 0s 651us/sample - loss: 1.3854 - accuracy: 0.8825 - val_loss: 9.0745 - val_accuracy: 0.6800
# Epoch 53/100
# 400/400 [==============================] - 0s 675us/sample - loss: 0.7246 - accuracy: 0.9275 - val_loss: 7.2034 - val_accuracy: 0.7300
# Epoch 54/100
# 400/400 [==============================] - 0s 681us/sample - loss: 1.2366 - accuracy: 0.9350 - val_loss: 18.2460 - val_accuracy: 0.5500
# Epoch 55/100
# 400/400 [==============================] - 0s 700us/sample - loss: 4.7955 - accuracy: 0.7825 - val_loss: 11.9284 - val_accuracy: 0.6500
# Epoch 56/100
# 400/400 [==============================] - 0s 679us/sample - loss: 2.6649 - accuracy: 0.8375 - val_loss: 15.4018 - val_accuracy: 0.6100
# Epoch 57/100
# 400/400 [==============================] - 0s 653us/sample - loss: 4.2579 - accuracy: 0.8300 - val_loss: 5.8929 - val_accuracy: 0.7100
# Epoch 58/100
# 400/400 [==============================] - 0s 779us/sample - loss: 2.2981 - accuracy: 0.8525 - val_loss: 10.5058 - val_accuracy: 0.6600
# Epoch 59/100
# 400/400 [==============================] - 0s 767us/sample - loss: 4.3527 - accuracy: 0.7900 - val_loss: 11.8462 - val_accuracy: 0.6100
# Epoch 60/100
# 400/400 [==============================] - 0s 734us/sample - loss: 2.3603 - accuracy: 0.8550 - val_loss: 6.3287 - val_accuracy: 0.6600
# Epoch 61/100
# 400/400 [==============================] - 0s 734us/sample - loss: 2.4013 - accuracy: 0.8375 - val_loss: 19.9647 - val_accuracy: 0.5700
# Epoch 62/100
# 400/400 [==============================] - 0s 714us/sample - loss: 2.9392 - accuracy: 0.8175 - val_loss: 16.9081 - val_accuracy: 0.5200
# Epoch 63/100
# 400/400 [==============================] - 0s 713us/sample - loss: 5.9127 - accuracy: 0.7325 - val_loss: 29.3799 - val_accuracy: 0.4300
# Epoch 64/100
# 400/400 [==============================] - 0s 715us/sample - loss: 7.0109 - accuracy: 0.7575 - val_loss: 5.4755 - val_accuracy: 0.7200
# Epoch 65/100
# 400/400 [==============================] - 0s 659us/sample - loss: 1.3038 - accuracy: 0.8975 - val_loss: 3.4916 - val_accuracy: 0.7600
# Epoch 66/100
# 400/400 [==============================] - 0s 699us/sample - loss: 2.3265 - accuracy: 0.8175 - val_loss: 4.3280 - val_accuracy: 0.7600
# Epoch 67/100
# 400/400 [==============================] - 0s 691us/sample - loss: 1.0467 - accuracy: 0.8925 - val_loss: 6.4414 - val_accuracy: 0.7400
# Epoch 68/100
# 400/400 [==============================] - 0s 662us/sample - loss: 0.5472 - accuracy: 0.9200 - val_loss: 5.6732 - val_accuracy: 0.7500
# Epoch 69/100
# 400/400 [==============================] - 0s 679us/sample - loss: 0.1572 - accuracy: 0.9650 - val_loss: 3.1516 - val_accuracy: 0.7700
# Epoch 70/100
# 400/400 [==============================] - 0s 683us/sample - loss: 0.1867 - accuracy: 0.9750 - val_loss: 4.8865 - val_accuracy: 0.7500
# Epoch 71/100
# 400/400 [==============================] - 0s 664us/sample - loss: 0.1126 - accuracy: 0.9850 - val_loss: 3.6455 - val_accuracy: 0.8200
# Epoch 72/100
# 400/400 [==============================] - 0s 696us/sample - loss: 0.3797 - accuracy: 0.9500 - val_loss: 7.0652 - val_accuracy: 0.6700
# Epoch 73/100
# 400/400 [==============================] - 0s 662us/sample - loss: 3.6515 - accuracy: 0.7925 - val_loss: 6.0924 - val_accuracy: 0.7300
# Epoch 74/100
# 400/400 [==============================] - 0s 664us/sample - loss: 1.0305 - accuracy: 0.9000 - val_loss: 4.3077 - val_accuracy: 0.7600
# Epoch 75/100
# 400/400 [==============================] - 0s 670us/sample - loss: 1.8962 - accuracy: 0.8750 - val_loss: 15.8911 - val_accuracy: 0.5900
# Epoch 76/100
# 400/400 [==============================] - 0s 654us/sample - loss: 3.1658 - accuracy: 0.8225 - val_loss: 4.9739 - val_accuracy: 0.7600
# Epoch 77/100
# 400/400 [==============================] - 0s 703us/sample - loss: 1.1709 - accuracy: 0.8925 - val_loss: 6.7488 - val_accuracy: 0.8200
# Epoch 78/100
# 400/400 [==============================] - 0s 688us/sample - loss: 2.6075 - accuracy: 0.8300 - val_loss: 4.5603 - val_accuracy: 0.7600
# Epoch 79/100
# 400/400 [==============================] - 0s 676us/sample - loss: 0.6265 - accuracy: 0.9400 - val_loss: 7.4680 - val_accuracy: 0.7400
# Epoch 80/100
# 400/400 [==============================] - 0s 649us/sample - loss: 1.9198 - accuracy: 0.8375 - val_loss: 4.4642 - val_accuracy: 0.7900
# Epoch 81/100
# 400/400 [==============================] - 0s 764us/sample - loss: 0.8603 - accuracy: 0.9275 - val_loss: 3.0897 - val_accuracy: 0.7600
# Epoch 82/100
# 400/400 [==============================] - 0s 690us/sample - loss: 0.4401 - accuracy: 0.9425 - val_loss: 4.7587 - val_accuracy: 0.7500
# Epoch 83/100
# 400/400 [==============================] - 0s 702us/sample - loss: 0.1969 - accuracy: 0.9675 - val_loss: 4.9288 - val_accuracy: 0.7600
# Epoch 84/100
# 400/400 [==============================] - 0s 675us/sample - loss: 0.3358 - accuracy: 0.9600 - val_loss: 3.2144 - val_accuracy: 0.8300
# Epoch 85/100
# 400/400 [==============================] - 0s 678us/sample - loss: 0.6871 - accuracy: 0.9350 - val_loss: 3.1824 - val_accuracy: 0.8000
# Epoch 86/100
# 400/400 [==============================] - 0s 675us/sample - loss: 0.8798 - accuracy: 0.9025 - val_loss: 4.4544 - val_accuracy: 0.7200
# Epoch 87/100
# 400/400 [==============================] - 0s 677us/sample - loss: 0.7076 - accuracy: 0.9125 - val_loss: 3.3533 - val_accuracy: 0.8000
# Epoch 88/100
# 400/400 [==============================] - 0s 680us/sample - loss: 0.3180 - accuracy: 0.9650 - val_loss: 5.7138 - val_accuracy: 0.8000
# Epoch 89/100
# 400/400 [==============================] - 0s 667us/sample - loss: 0.4464 - accuracy: 0.9375 - val_loss: 6.2129 - val_accuracy: 0.7300
# Epoch 90/100
# 400/400 [==============================] - 0s 688us/sample - loss: 1.9499 - accuracy: 0.8550 - val_loss: 5.6096 - val_accuracy: 0.7800
# Epoch 91/100
# 400/400 [==============================] - 0s 755us/sample - loss: 2.0062 - accuracy: 0.8500 - val_loss: 5.2042 - val_accuracy: 0.7700
# Epoch 92/100
# 400/400 [==============================] - 0s 747us/sample - loss: 1.9060 - accuracy: 0.8550 - val_loss: 4.1040 - val_accuracy: 0.7400
# Epoch 93/100
# 400/400 [==============================] - 0s 728us/sample - loss: 0.3793 - accuracy: 0.9500 - val_loss: 4.4756 - val_accuracy: 0.7900
# Epoch 94/100
# 400/400 [==============================] - 0s 713us/sample - loss: 0.3672 - accuracy: 0.9525 - val_loss: 3.5401 - val_accuracy: 0.7500
# Epoch 95/100
# 400/400 [==============================] - 0s 721us/sample - loss: 0.2785 - accuracy: 0.9500 - val_loss: 6.6164 - val_accuracy: 0.6600
# Epoch 96/100
# 400/400 [==============================] - 0s 718us/sample - loss: 1.1774 - accuracy: 0.9025 - val_loss: 2.6201 - val_accuracy: 0.8300
# Epoch 97/100
# 400/400 [==============================] - 0s 697us/sample - loss: 3.5055 - accuracy: 0.8125 - val_loss: 15.3545 - val_accuracy: 0.5300
# Epoch 98/100
# 400/400 [==============================] - 0s 686us/sample - loss: 1.0602 - accuracy: 0.9050 - val_loss: 3.8077 - val_accuracy: 0.7600
# Epoch 99/100
# 400/400 [==============================] - 0s 726us/sample - loss: 1.0386 - accuracy: 0.8675 - val_loss: 5.4027 - val_accuracy: 0.7000
# Epoch 100/100
# 400/400 [==============================] - 0s 696us/sample - loss: 1.6270 - accuracy: 0.8375 - val_loss: 4.4926 - val_accuracy: 0.6600

# %% [markdown]
# Plot the training and validation accuracy:

# %%
import seaborn as sns
sns.set()

acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, '-', label='Training Accuracy')
plt.plot(epochs, val_acc, ':', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.plot()
# Out:
# []

# %% [markdown]
# And... finally, use the test data to generate a confusion matrix to visualize how the network performs.

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import sklearn
print(sklearn.__version__)

sns.reset_orig()
y_pred = model.predict(x_test)

cm = confusion_matrix(y_test, y_pred.argmax(axis=1))
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=faces.target_names)
disp.plot()
# Out:
# 0.24.2

# %% [markdown]
# # Keras Callbacks:
#
# Want to check in on your network while it's training? Keras's [_callbacks API_](https://keras.io/api/callbacks/) allows us to do so

# %% [markdown]
# Let's demo the callbacks API using MNIST, a very common computer vision dataset of handwritten digit recognition.

# %%
from tensorflow.keras.datasets import mnist

(train_images, y_train), (test_images, y_test) = mnist.load_data()
print('train_images: ' + str(train_images.shape))
print('y_train: ' + str(y_train.shape))
print('test_images: ' + str(test_images.shape))
print('y_test: ' + str(y_test.shape))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step
# train_images: (60000, 28, 28)
# y_train: (60000,)
# test_images: (10000, 28, 28)
# y_test: (10000,)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.tick_params(axis='both', which='both', bottom=False, top=False, left=False, right=False, labelbottom=False, labelleft=False)
plt.imshow(train_images[0], cmap=plt.cm.gray_r)

# %% [markdown]
# Plot the first 50 images from MNIST:

# %%
fig, axes = plt.subplots(5, 10, figsize=(12, 7), subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(train_images[i], cmap=plt.cm.gray_r)
    ax.text(0.45, 1.05, str(y_train[i]), transform=ax.transAxes)

# %% [markdown]
# ## Check to make sure it's balanced:

# %%
plt.xticks([])
plt.hist(y_train, rwidth=0.9)
# Out:
# (array([5923., 6742., 5958., 6131., 5842., 5421., 5918., 6265., 5851.,
#         5949.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Prepare the input data by flattening the pixel arrays and normalizing the pixel valuse by dividing thben by 255.

# %%
x_train = train_images.reshape(60000, 28 * 28) / 255
x_test = test_images.reshape(10000, 28 * 28) / 255

# %% [markdown]
# Create a neural network with a `softmax` output layer for the classification:

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(128, activation='relu', input_dim=28 * 28))
model.add(Dense(10, activation='softmax'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 128)               100480
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Call `fit` to train the model. Stop training if the validation accuracy fails to imporve for 5 consecutive epochs, and reduce the learning rate if the validation accuracy fails to imporve for 3 consecutive epochs.

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stop = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=3)

hist = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100, batch_size=50,
                 callbacks=[early_stop, reduce_lr])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.2842 - accuracy: 0.9205 - val_loss: 0.1500 - val_accuracy: 0.9549
# Epoch 2/100
# 60000/60000 [==============================] - 4s 66us/sample - loss: 0.1272 - accuracy: 0.9630 - val_loss: 0.1085 - val_accuracy: 0.9672
# Epoch 3/100
# 60000/60000 [==============================] - 4s 69us/sample - loss: 0.0889 - accuracy: 0.9734 - val_loss: 0.0826 - val_accuracy: 0.9763
# Epoch 4/100
# 60000/60000 [==============================] - 4s 75us/sample - loss: 0.0665 - accuracy: 0.9800 - val_loss: 0.0770 - val_accuracy: 0.9767
# Epoch 5/100
# 60000/60000 [==============================] - 4s 71us/sample - loss: 0.0517 - accuracy: 0.9843 - val_loss: 0.0780 - val_accuracy: 0.9755
# Epoch 6/100
# 60000/60000 [==============================] - 4s 68us/sample - loss: 0.0408 - accuracy: 0.9876 - val_loss: 0.0757 - val_accuracy: 0.9773
# Epoch 7/100
# 60000/60000 [==============================] - 4s 69us/sample - loss: 0.0344 - accuracy: 0.9893 - val_loss: 0.0759 - val_accuracy: 0.9783
# Epoch 8/100
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.0259 - accuracy: 0.9922 - val_loss: 0.0812 - val_accuracy: 0.9768
# Epoch 9/100
# 60000/60000 [==============================] - 4s 70us/sample - loss: 0.0222 - accuracy: 0.9938 - val_loss: 0.0718 - val_accuracy: 0.9790
# Epoch 10/100
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.0188 - accuracy: 0.9941 - val_loss: 0.0759 - val_accuracy: 0.9778
# Epoch 11/100
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.0144 - accuracy: 0.9959 - val_loss: 0.0714 - val_accuracy: 0.9803
# Epoch 12/100
# 60000/60000 [==============================] - 4s 74us/sample - loss: 0.0124 - accuracy: 0.9962 - val_loss: 0.0802 - val_accuracy: 0.9768
# Epoch 13/100
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.0106 - accuracy: 0.9970 - val_loss: 0.0811 - val_accuracy: 0.9782
# Epoch 14/100
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.0100 - accuracy: 0.9969 - val_loss: 0.0824 - val_accuracy: 0.9794
# Epoch 15/100
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.0040 - accuracy: 0.9992 - val_loss: 0.0790 - val_accuracy: 0.9794
# Epoch 16/100
# 60000/60000 [==============================] - 4s 74us/sample - loss: 0.0024 - accuracy: 0.9998 - val_loss: 0.0767 - val_accuracy: 0.9813
# Epoch 17/100
# 60000/60000 [==============================] - 4s 70us/sample - loss: 0.0024 - accuracy: 0.9997 - val_loss: 0.0795 - val_accuracy: 0.9800
# Epoch 18/100
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.0021 - accuracy: 0.9998 - val_loss: 0.0816 - val_accuracy: 0.9797
# Epoch 19/100
# 60000/60000 [==============================] - 4s 71us/sample - loss: 0.0017 - accuracy: 0.9999 - val_loss: 0.0847 - val_accuracy: 0.9792
# Epoch 20/100
# 60000/60000 [==============================] - 4s 69us/sample - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0811 - val_accuracy: 0.9814
# Epoch 21/100
# 60000/60000 [==============================] - 4s 68us/sample - loss: 7.7828e-04 - accuracy: 1.0000 - val_loss: 0.0845 - val_accuracy: 0.9807
# Epoch 22/100
# 60000/60000 [==============================] - 4s 70us/sample - loss: 7.8139e-04 - accuracy: 1.0000 - val_loss: 0.0869 - val_accuracy: 0.9804
# Epoch 23/100
# 60000/60000 [==============================] - 4s 67us/sample - loss: 6.1029e-04 - accuracy: 1.0000 - val_loss: 0.0848 - val_accuracy: 0.9805
# Epoch 24/100
# 60000/60000 [==============================] - 4s 68us/sample - loss: 4.3717e-04 - accuracy: 1.0000 - val_loss: 0.0852 - val_accuracy: 0.9813
# Epoch 25/100
# 60000/60000 [==============================] - 4s 69us/sample - loss: 3.9055e-04 - accuracy: 1.0000 - val_loss: 0.0859 - val_accuracy: 0.9814

# %%
import seaborn as sns
sns.set()

acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, '-', label='Training Accuracy')
plt.plot(epochs, val_acc, ':', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.plot()
# Out:
# []
